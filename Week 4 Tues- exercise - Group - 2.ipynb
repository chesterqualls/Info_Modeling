# %% [markdown]
# ## Week 4 Tuesday Exercise
#
# **Assignment**: This exercise will use pandas to explore tweet data.  Specifically, you will:
#
# * Read a file of tweets into a dataframe
# * Use pandas to describe and analyze the data
# * Discuss how these methods might be used by relevant firms
#
# For this exercise, you will have to complete all the tasks within this notebook, save the entire notebook, and then upload into the Week 4 Tuesday Assignment for your group on BlackBoard. Save this notebook with a new name with the following format:
#
# **Week_4_Tues_Exercise_Group_group_number.ipynb**
#
# These in-class exercises are designed to allow you to explore Python with your group and **DO NOT** include step-by-step directions or answers that have only one possibility. Use your team and other resources to determine how best to complete them. Make sure before you turn in your notebook that it runs without errors and the requested output is visible in the notebook. If you go through multiple steps in your code, make sure all those steps are included so that we can evaluate your work.

# %% [markdown]
# First off, unzip and read the tweet data from the file from the datasets folder named 'pokemon.zip' into a dataframe and examine the dataset.
#
# **Analyze Tweet Data**

# %%
# This code block is to make the tweets_list function available. You don't need to modify anything here, just run it.

import json

def tweets_list(filename):
    """
    Read lines from filepath and file into a list of dictionaries.
    
    Parameters
    ----------
    filename: str
    """
    tweets = []
    f = open(filename, 'r')
    for line in f:
        try:
            tweet = json.loads(line)
            tweets.append(tweet)
        except:
            continue
    return tweets

# %%
# Read file with tweet data into a variable using tweets_list
# pokemon.zip needs to be unzipped into pokemon.txt in the dataset directory before running this

data = tweets_list('./datasets/pokemon.txt')

# %%
# What datatype is data
type(data)
# Out:
# list

# %%
# Now, read the data variable into a dataframe
import pandas as pd

tweet_df = pd.DataFrame(data)

# %%
# How many tweets are in the tweet dataframe?
len(tweet_df)
# Out:
# 2859

# %%
# Let's take a look at what is in the datframe

print tweet_df.ix[0,:]
# Out:
# contributors                                                              None
# coordinates                                                               None
# created_at                                      Tue Nov 24 22:23:50 +0000 2015
# entities                     {u'user_mentions': [], u'symbols': [], u'hasht...
# extended_entities                                                          NaN
# favorite_count                                                               0
# favorited                                                                False
# filter_level                                                               low
# geo                                                                       None
# id                                                          669280290095939584
# id_str                                                      669280290095939584
# in_reply_to_screen_name                                                   None
# ...

# %%
# How many of the tweets are retweets? If they are not retweeted, they have no data.
# assume defined as retweeted_status value is not equal to NaN


# OPTION 1: len(tweet_df[(tweet_df['retweeted_status']>=0)])
tweet_df['retweeted_status'].count()
# Out:
# 1076

# %%
# How many of the tweets are determined to be English?

len(tweet_df[(tweet_df['lang']=='en')])
# Out:
# 1709

# %% [markdown]
# With nested data like this, you can unpack individual columns with multiple values into their own column. The syntax is beyond the scope of this course, but is as follows:
# ```
# dataframe['new column'] = dataframe['column to unpack'].map(lambda tweet: tweet['key to unpack'])
# ```

# %%
# This code creates a new column called 'user_location' from the nested data in the user column
tweet_df['user_location'] = tweet_df['user'].map(lambda tweet: tweet['location'])

# %%
# How many tweets originated in the user location of Hyrule?
len(tweet_df[(tweet_df['user_location']=='Hyrule')])
# Out:
# 13

# %%
# Let's look at examples of tweets where the language is undefined

tweet_df[(tweet_df['lang']=='und')]
# Out:
#      contributors coordinates                      created_at  \
# 0            None        None  Tue Nov 24 22:23:50 +0000 2015
# 4            None        None  Tue Nov 24 22:23:54 +0000 2015
# 5            None        None  Tue Nov 24 22:23:54 +0000 2015
# 6            None        None  Tue Nov 24 22:23:54 +0000 2015
# 7            None        None  Tue Nov 24 22:23:55 +0000 2015
# 8            None        None  Tue Nov 24 22:23:55 +0000 2015
# 9            None        None  Tue Nov 24 22:23:55 +0000 2015
# 10           None        None  Tue Nov 24 22:23:56 +0000 2015
# 11           None        None  Tue Nov 24 22:23:56 +0000 2015
# 12           None        None  Tue Nov 24 22:23:56 +0000 2015
# 93           None        None  Tue Nov 24 22:27:00 +0000 2015
# 131          None        None  Tue Nov 24 22:27:56 +0000 2015
# 133          None        None  Tue Nov 24 22:27:59 +0000 2015
# 135          None        None  Tue Nov 24 22:28:01 +0000 2015
# ...

# %% [markdown]
# ## Written Response 1
# (Enter Your Response in This Cell)
#
# * **How do you think the Pokémon Company uses streaming data like this?**
#
# > Some of the many ways that Pokemon can use this streaming data are:
#
# > To look for correlations between trends in twitter activity and Pokemon sales patterns and utilization. This data could result in descriptive, predictive or even prescriptive results that the Pokemon company can use. Some of this explored further below.
#
# > Watch for influential users in the community, see who is being re-tweeted the most and who seems to lead the discussions. Once identified they may be able to engage these users, perhaps even pay them. They could run tests using these people such as testing their new ideas for characters, plots, etc.
#
# > Watch for usefule ideas. These could be new characters, or game features or story plots.  The people tweeting are engaged users and they have good ideas about what they would like to see from Pokemon. There are lots of ideas put out there
#
# * **What specific applications could it have for product development?**
#
# > Tweet activity could be incorporated into online pokemon games. As mentioned above, a new character or feature may be identified from the tweets.  Pokemon (Nintendo perhaps) could include in their games a way to test the new ideas they discover. This could be brought directly into the game so that users could directly vote on a feature.
#
# > A game for example could also have an "energy level" tied to the sentiment on twitter for a specific character at the time.  This would be a feature that within the game the player can't control, but if they get engaged with the Pokemon community on Twitter they could boost the sentiment and help their character during play.  Or they could influence the sentiment negatively decreasing the strength of a character they are up against, or dislike.  This would extend the dynamics of the game play beyond the game itself and add a new level of interest. Could also go very wrong.
#
#
# * **What other streaming datasets (internal or external) might the Pokémon Company use with the Twitter data?**
#
# > They could combine twitter data with POS data from vendors such as GameStop, Walmart and Target to watch for patterns, relationships and predictors. First looking for trends in historical data and then developing prescriptive steps.  Walmart for example is increasingly allowing their suppliers to have access to relevant POS data they keep so that both companies gain benefits.  So internal data, combined with external POS data and Twitter feeds could provide tons of information for them.
#
# > They could include weather data and look for coorelations between different types of weather and Pokemon utilization in those ares. This would be particularly interesting if they could track online game play with weather.  Do people play online more when it's not nice out, or is it the same?  Or does it matter where they live, and what typical weather is? For example in Seattle it is more predictably raining, but in Phoenix it is sunny more often.  So is it rain that you want to watch in Seattle?  Or perhaps in that case nice weather, such as sunny skies changes the game play, but in Phoenix rain or monsoons are more likely to change the factors.  But in both cases knowing when there are power or internet outages would certainly affect online usage.

# %% [markdown]
# ## Written Response 2
# (Enter Your Response in This Cell)
#
# **How could you determine if a specific tweet had a negative or positive sentiment?** (use specific fields from the tweet data in your response)
#
# > If we are looking at the single tweet itself for a negative or positive sentiment...
#
# > We could filter data in the [source] or [text] columns looking indictors of positive or negative sentiment (e.g. emoticons, specific words, etc).  The source column could tell us a bit about sentiment. For example if the source is a user cell phone or their laptop using the twitter app then it may not be as critical as one posted through a twitter app tie in to user board where people discuss the games or pokemon universe.  And another source could be a direct repost with comment from an official pokemon or nintendo site, such as when they provide a button to tweet about this.
#
# > The text itself can be analysed for positive or negative sentiment.  According to a Wikipedia article on this (https://en.wikipedia.org/wiki/Sentiment_analysis)the methods for this "can be grouped into four main categories: keyword spotting, lexical affinity, statistical methods, and concept-level techniques"
#
# > However, if we are looking for the affect of a single tweet on a group, or community we may look at fields such as [retweeted_status] and [retweet_count] along with [created_at],[timestamp_ms] and the previous methods for sentiment analysis to see how deep and how rapidly a positive or negative sentiment is spreading.  If spreading rapidly it may be an issue the Public Relations department should deal with sooner rather than later.  On the other hand, if an comment is retweeted a couple times and then dies out, it may not need to be addressed.  A positive sentiment, whether shallow, deep or rapid could be identified and exploited (for lack of better word) by Pokemon within the community.  Highlighting the Pokemon game players who are talking about a positive aspect of the game can benefit everyone.
#
# >As mentioned above you could find those people who are most influential in the community sentiment by using the analysis methods and looking at the [in_reply_to_screen_name], or [quoted_status_id], or even [favorite_count] fields for example to follow back to the person starting the conversations.

# %% [markdown]
# ## Written Response 3
# (Enter Your Response in This Cell)
#
# **Picking a company where one of you works, what streaming data sources might be useful for you and what sorts of research questions could they inform?**
#
# > We will look at Intel where Mike works.
#
# > They could ask research questions surrounding a new product launch.  For example, when a new product is launched how does the "buzz" for this product grow in the specific target community for that product.
#
# > Intel may have thier own twitter account where they announce the new products, they could use the beta feature for contributors and allow both marketing and sales people to contribute (as well as providing tweets that these Intel people could use on their own twitter accounts. They could also use typical "press kits" which are released to various media outlets and reporters that cover these areas.
#
# > After this new product launch Intel could monitor tweet activity where the new product is mentioned. This could be compared to historical tweet activity from previous similar products. The result could be predictive of sales and lead to decisions relating to manufacturing/stocking levels as well as adjustments to marketing strategy.
#
# > The re-tweets and counts could be watched to see where the end users are picking up and reading their information?  Are they getting it from news sources, magazines, etc.?  Or are they getting their information directly from Intel's twitter account, or from influential sales people (like Mike)?
#
# >Intel could also watch for tweets which contain blog posts and eventually analyize the blog feed and comments in combination with the twitter feed.  This may tell Intel that the traditional media is not getting out the message as well as a few bloggers, or the opposite.
#
# > By also traking locations and plotting them on a map, Intel could compare the "buzz" with actual sales data and actually watch it develp on the map. Both positive and negative sentiment can be tracked and can be compared to sales data (by location) as those figures begin to roll in.
#
# > Qualititative search terms could be monitored as well and could yield prescriptive results for targeted marketing actgivities. As mentioned in a previous question this information can direct the responses of marketing and public relations departments within Intel If the PR department sees a negative sentiment developing, they can work to combat it, and then of course track how well their approach is working.  This could also inform the relationships Intel has with venders or resellers (if any). Intel can provide suggestions for resellers depending on what they see happening.

# %% [markdown]
# ## Written Response 4
# (Enter Your Response in This Cell)
#
# Review this post about the Twitter metadata you were using- https://blog.twitter.com/2013/introducing-new-metadata-for-tweets
#
# * **How might some tweets lead to the language attribute being inaccurate or undetermined?**
#
# > Tweets may be inaccurate or undetermed if there is a mix of languages in the tweet, or if tweets only contain things like: urls, emoticons, hashtags, without any real text to determine the tweet.
#
# > Tweets in languages such as French, Spanish, English or Klingon may we easily determined but lessor known languages both on this planet and extra-terrestrial may be difficult because the language detectors aren't yet written for less common languages.
#
# > A tweet could also be an encoded string in binary, or hexidecimal or perhaps Base64 (as in the Saturday assignment) and not be counted as a written or signed language for communication.

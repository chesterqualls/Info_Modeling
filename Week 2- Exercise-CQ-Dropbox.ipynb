# %% [markdown]
# ## Week 2 Exercise
#
# **Assignment**: This exercise will use a live, publicly accessable API to collect multiple categories of data in order to conduct analyses and create visulizations.  Spefically, you will:
#
# * Collect data from a public website
# * Read data into dataframes
# * Develop a research question(s)
# * Inform that research question with visualizations
# * Inform that research question with basic statistics
# * Provide a short write up of your analysis
# * Generalize this analysis to "big data"
#
# For this exercise, you will have to complete all the tasks within this notebook, save the entire notebook, and then upload into the Week 2 Assignment for your group on BlackBoard. Save this notebook with a new name with the following format:
#
# **Week_2_Exercise_Group_group_number.ipynb**
#
# These in-class exercises are designed to allow you to explore Python with your group and **DO NOT** include step-by-step directions or answers that have only one possibility. Use your team and other resources to determine how best to complete them. Make sure before you turn in your notebook that it runs without errors and the requested output is visible in the notebook. If you go through multiple steps in your code, make sure all those steps are included so that we can evaluate your work.

# %% [markdown]
# ## Basketball Statistics
#
# For this exercise, we are going to use the National Basketball Association's statitics site. We will be using a Python library called [requests](http://docs.python-requests.org/en/latest/) to send a URL to their http://stats.nba.com site to query it for player shot data. Requests makes it easy to do "web scaping" like this. The data returned from the website is JSON, but we will reading that JSON into a pandas dataframe for analysis.
#
# In order to make the retreival of the data easier, we have written a function that will return the shot statistics for any player for the 2014-2015 season. You have already been using simple functions like <code>type</code> and <code>id</code>, but in this case we are writing our own. Once you run the code in the cell below, the function <code>get_shot_stats</code> will be available for you to use just as any other Python function. Our function has one input parameter which is the NBA's player id.
#
# Run the code in the following block to make the function available for use in the notebook namespace.

# %%
import requests
import pandas as pd

def get_shot_stats(player_id):
    """
    Return a dataframe of player shot statistics from the NBA API.
    
    Keyword arguments:
    player_id: the integer player id from http://stats.nba.com
    """

    shot_chart_url = 'http://stats.nba.com/stats/shotchartdetail?CFID=33&CFPAR'\
                    'AMS=2014-15&ContextFilter=&ContextMeasure=FGA&DateFrom=&D'\
                    'ateTo=&GameID=&GameSegment=&LastNGames=0&LeagueID=00&Loca'\
                    'tion=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&'\
                    'PaceAdjust=N&PerMode=PerGame&Period=0&PlayerID={}&Plu'\
                    'sMinus=N&Position=&Rank=N&RookieYear=&Season=2014-15&Seas'\
                    'onSegment=&SeasonType=Regular+Season&TeamID=0&VsConferenc'\
                    'e=&VsDivision=&mode=Advanced&showDetails=0&showShots=1&sh'\
                    'owZones=0'.format(player_id)
                    
    response = requests.get(shot_chart_url)
    headers = response.json()['resultSets'][0]['headers']
    shots = response.json()['resultSets'][0]['rowSet']
    shot_df = pd.DataFrame(shots, columns=headers)
    
    return shot_df

# %% [markdown]
# Now, let's use the function to collect data for Phoenix Sun's player Brandon Knight. We happen to know Brandon Knight's id number is 202688.

# %%
# Assign Brandon's id to a variable.
brandon = 202688

# %%
# Use our fucntion to get Brandon's stats and assign the returned dataframe to var.
brandon_shots = get_shot_stats(brandon)

# %%
# Print the dataframe to make sure it worked.
print brandon_shots
# Out:
#              GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID     PLAYER_NAME  \
# 0    Shot Chart Detail  0021400004             10     202688  Brandon Knight
# 1    Shot Chart Detail  0021400004             18     202688  Brandon Knight
# 872                 46       ...                  Jump Shot  3PT Field Goal
# 873                 20       ...                  Jump Shot  2PT Field Goal
# 874                 27       ...          Running Bank shot  2PT Field Goal
# 875                 54       ...         Driving Layup Shot  2PT Field Goal
# 876                 18       ...                  Jump Shot  3PT Field Goal
# 877                 48       ...           Pullup Jump shot  2PT Field Goal
# 878                 19       ...                  Jump Shot  2PT Field Goal
# 879                 41       ...                  Jump Shot  3PT Field Goal
# 880                 43       ...                  Jump Shot  3PT Field Goal
# 881                 53       ...                 Layup Shot  2PT Field Goal
# 882                 33       ...                  Jump Shot  3PT Field Goal
# 883                 11       ...                  Jump Shot  3PT Field Goal
# 884                 49       ...                  Jump Shot  3PT Field Goal
# 885                 13       ...        Step Back Jump shot  2PT Field Goal
# 886                 51       ...                  Jump Shot  3PT Field Goal
# 887                 30       ...                  Jump Shot  2PT Field Goal
#
#            SHOT_ZONE_BASIC         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0          Restricted Area              Center(C)  Less Than 8 ft.
# 1                Mid-Range              Center(C)        16-24 ft.
# 2          Restricted Area              Center(C)  Less Than 8 ft.
# 3        Above the Break 3  Right Side Center(RC)          24+ ft.
# 4          Restricted Area              Center(C)  Less Than 8 ft.
# 5           Right Corner 3          Right Side(R)          24+ ft.
# 6          Restricted Area              Center(C)  Less Than 8 ft.
# 7                Mid-Range   Left Side Center(LC)        16-24 ft.
# 8        Above the Break 3  Right Side Center(RC)          24+ ft.
# 9          Restricted Area              Center(C)  Less Than 8 ft.
# 10          Right Corner 3          Right Side(R)          24+ ft.
# 11               Mid-Range              Center(C)        16-24 ft.
# 12               Mid-Range  Right Side Center(RC)        16-24 ft.
# 13               Mid-Range           Left Side(L)        16-24 ft.
# 14         Restricted Area              Center(C)  Less Than 8 ft.
# 15   In The Paint (Non-RA)              Center(C)  Less Than 8 ft.
# 16               Mid-Range   Left Side Center(LC)        16-24 ft.
# 17       Above the Break 3   Left Side Center(LC)          24+ ft.
# 18           Left Corner 3           Left Side(L)          24+ ft.
# 19               Mid-Range   Left Side Center(LC)        16-24 ft.
# 20         Restricted Area              Center(C)  Less Than 8 ft.
# 21         Restricted Area              Center(C)  Less Than 8 ft.
# 22       Above the Break 3   Left Side Center(LC)          24+ ft.
# 23       Above the Break 3              Center(C)          24+ ft.
# 24         Restricted Area              Center(C)  Less Than 8 ft.
# 25               Mid-Range           Left Side(L)         8-16 ft.
# 26         Restricted Area              Center(C)  Less Than 8 ft.
# 27   In The Paint (Non-RA)              Center(C)         8-16 ft.
# 28       Above the Break 3   Left Side Center(LC)          24+ ft.
# 29          Right Corner 3          Right Side(R)          24+ ft.
# ..                     ...                    ...              ...
# 858          Left Corner 3           Left Side(L)          24+ ft.
# 859              Mid-Range  Right Side Center(RC)        16-24 ft.
# 860              Mid-Range              Center(C)        16-24 ft.
# 861      Above the Break 3   Left Side Center(LC)          24+ ft.
# 862      Above the Break 3   Left Side Center(LC)          24+ ft.
# 863      Above the Break 3   Left Side Center(LC)          24+ ft.
# 864  In The Paint (Non-RA)          Right Side(R)         8-16 ft.
# 865              Mid-Range   Left Side Center(LC)        16-24 ft.
# 866              Mid-Range           Left Side(L)        16-24 ft.
# 867  In The Paint (Non-RA)              Center(C)  Less Than 8 ft.
# 868        Restricted Area              Center(C)  Less Than 8 ft.
# 869  In The Paint (Non-RA)              Center(C)  Less Than 8 ft.
# 870              Mid-Range          Right Side(R)        16-24 ft.
# 871  In The Paint (Non-RA)           Left Side(L)         8-16 ft.
# 872      Above the Break 3   Left Side Center(LC)          24+ ft.
# 873              Mid-Range          Right Side(R)         8-16 ft.
# 874  In The Paint (Non-RA)              Center(C)  Less Than 8 ft.
# 875        Restricted Area              Center(C)  Less Than 8 ft.
# 876      Above the Break 3   Left Side Center(LC)          24+ ft.
# 877              Mid-Range   Left Side Center(LC)        16-24 ft.
# 878              Mid-Range  Right Side Center(RC)        16-24 ft.
# 879      Above the Break 3              Center(C)          24+ ft.
# 880      Above the Break 3   Left Side Center(LC)          24+ ft.
# 881        Restricted Area              Center(C)  Less Than 8 ft.
# 882      Above the Break 3   Left Side Center(LC)          24+ ft.
# 883      Above the Break 3              Center(C)          24+ ft.
# 884      Above the Break 3   Left Side Center(LC)          24+ ft.
# 885              Mid-Range           Left Side(L)        16-24 ft.
# 886      Above the Break 3   Left Side Center(LC)          24+ ft.
# 887        Restricted Area              Center(C)  Less Than 8 ft.
#
#     SHOT_DISTANCE  LOC_X  LOC_Y  SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG
# 0               1    -11     14                    1               1
# 1              19    -18    195                    1               0
# 2               0     -2      7                    1               1
# 3              25    130    225                    1               0
# 4               1      8     -6                    1               0
# 5              23    233      4                    1               0
# 6               2    -13     23                    1               0
# 7              22    -90    201                    1               0
# 8              26    143    219                    1               1
# 9               1     -7      9                    1               0
# 10             23    230     11                    1               1
# 11             16      0    167                    1               0
# 12             16    103    135                    1               0
# 13             16   -139     88                    1               1
# 14              2    -19     15                    1               0
# 15              6      4     64                    1               0
# 16             21    -90    195                    1               0
# 17             27    -93    258                    1               0
# 18             22   -223      1                    1               0
# 19             18   -105    156                    1               0
# 20              0      1      6                    1               1
# 21              2     15     22                    1               0
# 22             27   -163    222                    1               0
# 23             26    -45    263                    1               1
# 24              3     34     15                    1               0
# 25             12    -87     96                    1               0
# 26              1    -15      3                    1               1
# 27             13    -64    119                    1               1
# 28             25   -141    217                    1               1
# 29             24    241     25                    1               0
# ..            ...    ...    ...                  ...             ...
# 858            23   -234      0                    1               1
# 859            20    133    157                    1               0
# 860            21    -45    209                    1               0
# 861            25    -86    238                    1               0
# 862            25    -90    238                    1               0
# 863            24    -86    225                    1               0
# 864            14     77    121                    1               1
# 865            17   -136    113                    1               0
# 866            16   -149     63                    1               0
# 867             5     26     48                    1               0
# 868             1    -13      4                    1               1
# 869             5     50      1                    1               0
# 870            16    152     72                    1               1
# 871            11    -75     88                    1               0
# 872            25   -213    135                    1               1
# 873            12    114     48                    1               0
# 874             7     10     72                    1               1
# 875             1     13      0                    1               1
# 876            27   -134    241                    1               1
# 877            17    -75    153                    1               0
# 878            19     77    183                    1               0
# 879            25     67    246                    1               0
# 880            25    -93    239                    1               0
# 881             1    -10      0                    1               1
# 882            24   -205    137                    1               0
# 883            24     54    242                    1               0
# 884            24    -87    233                    1               0
# 885            16   -166     -2                    1               0
# 886            25   -134    217                    1               0
# 887             3     34      4                    1               0
#
# [888 rows x 21 columns]

# %% [markdown]
# With larger dataframe like this, returning the columns attribute via <code>df.columns</code> is a convienent way to see the column names without printing the entire dataframe.
#
# Using your knowledge of data selection, indexing, boolean masks, and the dataframe function <code>.sum()</code>, print out the number of baskets Brandon made both playing for the Suns and the Bucks.

# %%
# Print the number of baskets Brandon made as a Sun.

print '\nThe number of baskets Brandon made as a Sun are {}'.format(len(brandon_shots[(brandon_shots
                                                ['TEAM_NAME']=='Phoenix Suns')& (brandon_shots['SHOT_MADE_FLAG']==1)]))
# Out:
# The number of baskets Brandon made as a Sun are 51

# %%
# Print the number of baskets Brandon made as a Buck.

print '\nThe number of baskets Brandon made as a Buck are {}'.format(len(brandon_shots[(brandon_shots
                                            ['TEAM_NAME']=='Milwaukee Bucks')& (brandon_shots['SHOT_MADE_FLAG']==1)]))
# Out:
# The number of baskets Brandon made as a Buck are 324

# %%
# Print the number of baskets Brandon made as a Buck.
#Copied above cell to see if I could place the number of baskets in the middle of text.

print '\nAs a Buck Brandon made *{}* baskets'.format(len(brandon_shots[(brandon_shots['TEAM_NAME']=='Milwaukee Bucks')
                                                                       & (brandon_shots['SHOT_MADE_FLAG']==1)]))
# Out:
# As a Buck Brandon made *324* baskets

# %% [markdown]
# The pandas selection and statistics functions offer a powerful tool to explore datasets like the one we collected from the NBA. Let's give you one more tool before we continue- visualization.
#
# In the next code block we are going to import a function that allows us to visualize Brandon's shots on a basketball court. Specifically, this function draws the court. When you are working with matplotlib plots in Python, you can think of each individual function as drawing a layer and the <code>draw_court</code> function will provide the court layer that you will plot on top of. Run the following code block to see that.

# %%
# Let's read in a helper function for drawing and set up plotting

import matplotlib.pyplot as plt
from draw_court import draw_court
# Thanks to Savvas Tjortjoglou for letting us use his code in our course!
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 10.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Call the helper function to draw a court

plt.figure('court')# Begin plotting a figure called court.
draw_court(outer_lines=True)# Call the draw_court function.
plt.xlim(-300,300)# Set the limits of the canvas for the x axis.
plt.ylim(-100,450)# Set the limits of the canvas for the y axis
plt.scatter(brandon_shots.LOC_X,brandon_shots.LOC_Y, alpha=.5)# Plot the points with alpha value to make semi-transparent.
plt.show()# Display the figure.

# %% [markdown]
# While we will look in more detail at plotting in a future lab, we want to give you one more plotting tool, <code>plt.scatter()</code>.
#
# The <code>plt.scatter()</code> allows you to create a scatter plot by passing in a matrix of x and y coordinates. Detailed documentation is here:
#
# * http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter
#
# The code in the following code block is a simple example of this using random data.

# %%
import numpy as np # Import NumPy to generate random numbers.

plt.figure('scatter')# Begin plotting a figure called scatter.
x = np.random.rand(5000)# Generate 5000 random points for the x axis.
y = np.random.rand(5000)# Generate a corresponding 5000 points for the y axis.
plt.xlim(0,1)# Set the limits of the canvas for the x axis.
plt.ylim(0,1)# Set the limits of the canvas for the y axis.
plt.scatter(x,y, alpha=.5)# Plot the points with alpha value to make semi-transparent.
plt.show()# Show the plot in the notebook.

# %% [markdown]
# Finally, if you want to generate dataframes for other players than Brandon, you can lookup player numbers at http://stats.nba.com/. Player numbers appear in the page query parameters as shown below:
#
# <img src="https://raw.githubusercontent.com/azbones/big_data/master/images/brandon.png">

# %% [markdown]
# ## Written Response 1:
# _(Enter Your Response in This Cell)_
#
# Develop and enter a research question in this markdown box that you can explore with the NBA data, dataframe functions, and plotting. Do not use Brandon Knight in this question.
#
# Specically, use scatter plots to plot player shot selection on the pyplot court image. Try to make the research question more interesting by exploring something beyond just shot selection for a single player across the whole season across the whole game.

# %%
# Write the code to collect the data to inform your research question.
jason = 1891
jason_stats = get_shot_stats(jason)

js_all = pd.DataFrame(jason_stats)
js_all.insert(21, 'SUCCESSFUL_SHOTS',js_all['SHOT_MADE_FLAG'])
js_all.insert(22, 'UNSUCCESSFUL_SHOTS',(js_all['SHOT_MADE_FLAG']-js_all['SHOT_ATTEMPTED_FLAG'])*-1)
#Count successful / count successful + unsuccessful
js_all.insert(23, 'PERCENT_COMPLETE',(js_all['SHOT_MADE_FLAG']/js_all['SHOT_ATTEMPTED_FLAG']))

js_all

# Use our fucntion to get Brandon's stats and assign the returned dataframe to var.
jason_shots = get_shot_stats(jason)

#1st quarter unsuccessful 3pt shots
Q1_3PT_U_shots = jason_shots[(jason_shots['PERIOD']==1) & (jason_shots['SHOT_MADE_FLAG']==0) & (jason_shots['SHOT_TYPE']=='3PT Field Goal')]

#1st quarter successful 3pt shots
Q1_3PT_S_shots = jason_shots[(jason_shots['PERIOD']==1) & (jason_shots['SHOT_MADE_FLAG']==1) & (jason_shots['SHOT_TYPE']=='3PT Field Goal')]

#2nd quarter unsuccessful 3pt shots
Q2_3PT_U_shots = jason_shots[(jason_shots['PERIOD']==2) & (jason_shots['SHOT_MADE_FLAG']==0) & (jason_shots['SHOT_TYPE']=='3PT Field Goal')]

#2nd quarter successful 3pt shots
Q2_3PT_S_shots = jason_shots[(jason_shots['PERIOD']==2) & (jason_shots['SHOT_MADE_FLAG']==1) & (jason_shots['SHOT_TYPE']=='3PT Field Goal')]

#3rd quarter unsuccessful 3pt shots
Q3_3PT_U_shots = jason_shots[(jason_shots['PERIOD']==3) & (jason_shots['SHOT_MADE_FLAG']==0) & (jason_shots['SHOT_TYPE']=='3PT Field Goal')]

#3rd quarter successful 3pt shots
Q3_3PT_S_shots = jason_shots[(jason_shots['PERIOD']==3) & (jason_shots['SHOT_MADE_FLAG']==1) & (jason_shots['SHOT_TYPE']=='3PT Field Goal')]

#4th quarter unsuccessful 3pt shots
Q4_3PT_U_shots = jason_shots[(jason_shots['PERIOD']==4) & (jason_shots['SHOT_MADE_FLAG']==0) & (jason_shots['SHOT_TYPE']=='3PT Field Goal')]

#4th quarter successful 3pt shots
Q4_3PT_S_shots = jason_shots[(jason_shots['PERIOD']==4) & (jason_shots['SHOT_MADE_FLAG']==1) & (jason_shots['SHOT_TYPE']=='3PT Field Goal')]

# %%
# Write code to present visualizations that inform your research question. 
# Remember, plot the court, plot the shots, and then "show" the figure.

import matplotlib.pyplot as plt
from draw_court import draw_court
# Thanks to Savvas Tjortjoglou for letting us use his code in our course!
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 10.0)

# Call the helper function to draw a court

plt.figure('court')# Begin plotting a figure called court.
draw_court(outer_lines=True)# Call the draw_court function.
plt.xlim(-300,300)# Set the limits of the canvas for the x axis.
plt.ylim(-100,450)# Set the limits of the canvas for the y axis

q1u = plt.scatter(Q1_3PT_U_shots.LOC_X,Q1_3PT_U_shots.LOC_Y, alpha=.25, color = 'b')
q1s = plt.scatter(Q1_3PT_S_shots.LOC_X,Q1_3PT_S_shots.LOC_Y, alpha=.95, color = 'b')

q2u = plt.scatter(Q2_3PT_U_shots.LOC_X,Q2_3PT_U_shots.LOC_Y, alpha=.25, color = 'r')
q2s = plt.scatter(Q2_3PT_S_shots.LOC_X,Q2_3PT_S_shots.LOC_Y, alpha=.95, color = 'r')

q3u = plt.scatter(Q3_3PT_U_shots.LOC_X,Q3_3PT_U_shots.LOC_Y, alpha=.25, color = 'm')
q3s = plt.scatter(Q3_3PT_S_shots.LOC_X,Q3_3PT_S_shots.LOC_Y, alpha=.95, color = 'm')

q4u = plt.scatter(Q4_3PT_U_shots.LOC_X,Q4_3PT_U_shots.LOC_Y, alpha=.25, color = 'k')
q4s = plt.scatter(Q4_3PT_S_shots.LOC_X,Q4_3PT_S_shots.LOC_Y, alpha=.95, color = 'k')

plt.legend((q1u,q1s,q2u,q2s,q3u,q3s,q4u,q4s),("Q1 missed", "Q1 Success","Q2 missed", "Q2 Success","Q3 missed", "Q3 Success","Q4 missed", "Q4 Success"),loc=9)

plt.show()# Display the figure.
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Write code to generate some basic statistics (like sum() or average()) to inform your research question.
# cool, I can just suggest updates here.
# try deleting , 'mean' from both successful and unsuccessful below and re-run the code
js_agg = js_all.groupby(['PERIOD', 'SHOT_TYPE']).agg({'SUCCESSFUL_SHOTS': ['sum'],
                                                      'UNSUCCESSFUL_SHOTS': ['sum'],
                                                      'PERCENT_COMPLETE': ['mean']})
js_agg
# Out:
#                       SUCCESSFUL_SHOTS UNSUCCESSFUL_SHOTS PERCENT_COMPLETE
#                                    sum                sum             mean
# PERIOD SHOT_TYPE
# 1      2PT Field Goal               13                 12         0.520000
#        3PT Field Goal               30                 49         0.379747
# 2      2PT Field Goal               23                 20         0.534884
#        3PT Field Goal               25                 43         0.367647
# 3      2PT Field Goal               14                 12         0.538462
#        3PT Field Goal               31                 52         0.373494
# 4      2PT Field Goal               12                 16         0.428571
#        3PT Field Goal               39                 53         0.423913
# 5      2PT Field Goal                0                  1         0.000000
#        3PT Field Goal                1                  0         1.000000

# %% [markdown]
# ## Written Response 2:
# _(Enter Your Response in This Cell)_
#
# Provide a short write up of what your analysis revealed.

# %% [markdown]
# ## Written Response 3:
# _(Enter Your Response in This Cell)_
#
# * How might data available from public websites be part of a "big data" strategy?
# * What might some of the challenges of this approach be?
